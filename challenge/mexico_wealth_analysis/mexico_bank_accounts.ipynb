# %% [markdown]
# # Introduction of World Bank Group API Python Library

# %% [markdown]
# The hope for this notebook was to provide some analysis into the data for the World Bank Group, however, after discovering this library I feel it is better to provide an introduction to the library. It may be helpful in creating notebooks/scripts that can pull data from a public API.

# %%
import pandas as pd
import numpy as np
import wbgapi as wb

# %%
wb.economy.info('MEX')
# Out:
# id    value       region    incomeLevel
# ----  ----------  --------  -------------
# MEX   Mexico      LCN       UMC
#       1 elements

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2025-04-15
# 3     Worldwide Governance Indicators                                       WGI              3  2024-11-05
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2025-02-26
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2024-06-25
# ...

# %%
wb.db = 33

# %%
print(wb.series.info())
# Out:
# id                             value
# -----------------------------  --------------------------------------------------------------------------------------------------------------
# account_t_d                    Account (% age 15+)
# account_t_d_1                  Account, female (% age 15+)
# account_t_d_2                  Account, male (% age 15+)
# account_t_d_3                  Account, income, poorest 40% (% age 15+)
# account_t_d_4                  Account, income, richest 60% (% age 15+)
# account_t_d_5                  Account (% ages 15-34)
# account_t_d_6                  Account (% ages 35-59)
# account_t_d_7                  Account (% age 60+)
# fin11q1                        SMEs with at least one female owner with a proportion of loans requiring collateral
# fin11q2                        SMEs with a proportion of loans requiring collateral
# fin14q1                        SMEs with at least one female owner with an outstanding loan or line of credit
# ...

# %%
wb.data.DataFrame(['s_policyholders_B2_life', 
                   's_policyholders_B2_nonlife',
                   'i_ATMs_pop',
                   'GPSS_5',
                   'gwp2_n',
                   'g20_t'], 'MEX') # most recent 5 years
# Out:
#                                 YR2011      YR2012     YR2013      YR2014  \
# series
# GPSS_5                      1016.89600  1310.63600  1435.8010  1503.83900
# g20_t                              NaN         NaN        NaN    29.42064
# gwp2_n                             NaN         NaN        NaN         NaN
# i_ATMs_pop                    43.71807    47.41737    47.2516    48.82582
# s_policyholders_B2_life      683.42230   763.21790   959.5758   944.56530
# s_policyholders_B2_nonlife   576.56000   951.07330  1051.5860  1274.03900
#
#                                 YR2015      YR2016    YR2017  YR2018  YR2019
# series
# GPSS_5                      1552.12500         NaN       NaN     NaN     NaN
# g20_t                              NaN         NaN  31.74051     NaN     NaN
# gwp2_n                             NaN         NaN  45.40566     NaN     NaN
# i_ATMs_pop                    51.06691    52.62772  53.53227     NaN     NaN
# ...
